# %% [markdown]
# Чистка данных

# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv('C:/Users/admin/Desktop/python repo/CountryGDP2.csv', header = None)

df_num = df._get_numeric_data()
df_num.head()
df_obj = df.select_dtypes(include='object')

# %%
df_num = df_num.applymap('{:.2f}'.format)

# %%
df_num.head()
# Out:
#         4        5        6        7        8        9        10       11  \
# 0      nan      nan      nan      nan      nan      nan      nan      nan
# 1      nan      nan      nan      nan      nan      nan      nan      nan
# 2      nan      nan      nan      nan      nan      nan      nan      nan
# 3      nan      nan      nan      nan      nan      nan      nan      nan
# 4  1960.00  1961.00  1962.00  1963.00  1964.00  1965.00  1966.00  1967.00
#
#         12       13  ...       52       53       54       55       56  \
# 0      nan      nan  ...      nan      nan      nan      nan      nan
# 1      nan      nan  ...      nan      nan      nan      nan      nan
# 2      nan      nan  ...      nan      nan      nan      nan      nan
# 3      nan      nan  ...      nan      nan      nan      nan      nan
# 4  1968.00  1969.00  ...  2008.00  2009.00  2010.00  2011.00  2012.00
#
#         57       58       59       60       61
# 0      nan      nan      nan      nan      nan
# ...

# %%
# Удалите первые 4 строки
df_num = df_num.drop(df_num.index[:5])

# Проверьте результат
df_num.head()
# Out:
#              4             5             6             7             8   \
# 5           nan           nan           nan           nan           nan
# 6  537777811.10  548888895.60  546666677.80  751111191.10  800000044.40
# 7           nan           nan           nan           nan           nan
# 8           nan           nan           nan           nan           nan
# 9           nan           nan           nan           nan           nan
#
#               9              10             11             12             13  \
# 5            nan            nan            nan            nan            nan
# 6  1006666638.00  1399999967.00  1673333418.00  1373333367.00  1408888922.00
# 7            nan            nan            nan            nan            nan
# 8            nan            nan            nan            nan            nan
# 9            nan            nan            nan            nan            nan
#
# ...

# %%
df_obj.head()
# Out:
#                    0                             1               2  \
# 0        Data Source  World Development Indicators             NaN
# 1                NaN                           NaN             NaN
# 2  Last Updated Date                       9/21/18             NaN
# 3                NaN                           NaN             NaN
# 4       Country Name                  Country Code  Indicator Name
#
#                 3
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4  Indicator Code

# %%
# Удалите первые 4 строки
df_obj = df_obj.drop(df_obj.index[:5])

# Проверьте результат
df_obj.head()
# Out:
#              0    1                  2               3
# 5        Aruba  ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 6  Afghanistan  AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 7       Angola  AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 8      Albania  ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 9      Andorra  AND  GDP (current US$)  NY.GDP.MKTP.CD

# %%
df_num = df_num.astype(float)

# %%
df_num.dtypes

# %%
df_num.head()
# Out:
#             4            5            6            7            8   \
# 5          NaN          NaN          NaN          NaN          NaN
# 6 537777811.10 548888895.60 546666677.80 751111191.10 800000044.40
# 7          NaN          NaN          NaN          NaN          NaN
# 8          NaN          NaN          NaN          NaN          NaN
# 9          NaN          NaN          NaN          NaN          NaN
#
#              9             10            11            12            13  ...  \
# 5           NaN           NaN           NaN           NaN           NaN  ...
# 6 1006666638.00 1399999967.00 1673333418.00 1373333367.00 1408888922.00  ...
# 7           NaN           NaN           NaN           NaN           NaN  ...
# 8           NaN           NaN           NaN           NaN           NaN  ...
# 9           NaN           NaN           NaN           NaN           NaN  ...
#
#               52             53             54              55  \
# ...

# %%
df = df_obj.join(df_num)

# %%
# Проверьте результат
df.head()
# Out:
#             0    1                  2               3            4   \
# 5        Aruba  ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 6  Afghanistan  AFG  GDP (current US$)  NY.GDP.MKTP.CD 537777811.10
# 7       Angola  AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 8      Albania  ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 9      Andorra  AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#             5            6            7            8             9   ...  \
# 5          NaN          NaN          NaN          NaN           NaN  ...
# 6 548888895.60 546666677.80 751111191.10 800000044.40 1006666638.00  ...
# 7          NaN          NaN          NaN          NaN           NaN  ...
# 8          NaN          NaN          NaN          NaN           NaN  ...
# 9          NaN          NaN          NaN          NaN           NaN  ...
#
#               52             53             54              55  \
# ...

# %%
headers = ['Country Name',
 'Country Code',
 'Indicator Name',
 'Indicator Code', 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]

# %%
df.columns = headers
df.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 5        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 6  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 537777811.10
# 7       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 8      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 9      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 5          NaN          NaN          NaN          NaN           NaN  ...
# 6 548888895.60 546666677.80 751111191.10 800000044.40 1006666638.00  ...
# 7          NaN          NaN          NaN          NaN           NaN  ...
# 8          NaN          NaN          NaN          NaN           NaN  ...
# 9          NaN          NaN          NaN          NaN           NaN  ...
#
#             2008           2009           2010            2011  \
# ...

# %%
# Сохраните обновленный датасет в CSV с нужным форматированием чисел
df.to_csv('CountryGDPFormatted.csv', index=False, sep=',')
