# %%
import pandas as pd 
df =pd.read_excel('C:/Users/admin/Desktop/python repo/events.xlsx')

# %%
df['Event_Time'] = pd.to_datetime(df['Event_Time']).dt.strftime('%m/%d/%Y %H:%M')

# %%
df
# Out:
#    Application_Number        Event_Time         Activity_Name  Resource  \
# 0     Application_174  03/01/2016 16:49  A_Create Application    User_1
# 1     Application_174  03/01/2016 16:49           A_Submitted    User_1
# 2     Application_174  03/01/2016 16:50             A_Concept    User_1
# 3     Application_524  03/01/2016 17:13  A_Create Application    User_1
# 4     Application_524  03/01/2016 17:13           A_Submitted    User_1
# 5     Application_524  03/01/2016 17:14             A_Concept    User_1
# 6     Application_881  03/01/2016 17:48  A_Create Application    User_1
# 7     Application_881  03/01/2016 17:48           A_Submitted    User_1
# 8     Application_881  03/01/2016 17:49             A_Concept    User_1
# 9     Application_634  03/01/2016 18:44  A_Create Application    User_1
# 10    Application_634  03/01/2016 18:44           A_Submitted    User_1
# 11    Application_634  03/01/2016 18:45             A_Concept    User_1
# ...

# %%
df.to_excel('updated_file.xlsx', index=False)
