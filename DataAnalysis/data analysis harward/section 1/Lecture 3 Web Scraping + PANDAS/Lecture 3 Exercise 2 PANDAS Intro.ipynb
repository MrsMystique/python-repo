# %% [markdown]
# # <img style="float: left; padding-right: 10px; width: 45px" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png"> CS109A Introduction to Data Science
#
# ## Lecture 3, Exercise 2: PANDAS Intro
#
#
# **Harvard University**<br/>
# **Fall 2020**<br/>
# **Instructors**: Pavlos Protopapas, Kevin Rader, and Chris Tanner
#
# ---
# ## **NOTE**: After running every cell, be sure to auto-grade your work by clicking 'Mark' in the lower-right corner. Otherwise, no credit will be given.

# %% [markdown]
# # Заголовок
#
# ** Упражнение 2: Pandas Intro **
#
# # Описание
#
# Как обсуждалось в классе, «Pandas» - это библиотека Python, которая содержит очень полезные структуры данных, включая DataFrames, что облегчает анализ исследовательского анализа (EDA).Здесь мы получаем практику с некоторыми элементарными функциями.

# %%
import pandas as pd

# %%
# import the CSV file
df = pd.read_csv("Student_SurveyFinal.csv")

# %% [markdown]
# # Панды Основы
# Давайте начнем с базовой функциональности панд!
#
# В ячейке ниже заполните заготовку, чтобы переменная `cols` хранила имена столбцов DF`.** ПРИМЕЧАНИЕ.Не нужно преобразовать это в список.

# %%
df.iloc[[0]]
# Out:
#   16Personalities Quiz.  You will need to first take the quiz located at https://www.16personalities.com/. This quiz will take about 10 miinutes. Select your personality letters below. E.g. ENTJ-A, INTP-A, etc.  \
# 0                                             ISFJ-A
#
#                    Major_1 Major_2            Minor_1 Minor_2 PDP_Status  \
# 0  Business Administration     NaN  Applied Analytics     NaN         No
#
#    Grad_Year Class_Standing   GPA  Semester_Units  ... Zip_Code_US  \
# 0       2024         Junior  3.98              16  ...       60015
#
#   Is_California_Home Languages_Spoken                            News_Source  \
# 0                 No              1.0  News Sites. (e.g. Wall Street Journal
#
#   Loves_to_Travel Foodie Purchase_Based_On_Sustainability  \
# 0             Yes    Yes                               No
#
#   Reusable_Water_Bottle Meals_Delivery_Service_Percent Ride_Share_Percent
# ...

# %%
### edTest(test_a) ###
cols = df.columns
cols
# Out:
# Index(['16Personalities Quiz.  You will need to first take the quiz located at https://www.16personalities.com/. This quiz will take about 10 miinutes. Select your personality letters below. E.g. ENTJ-A, INTP-A, etc.',
#        'Major_1', 'Major_2', 'Minor_1', 'Minor_2', 'PDP_Status', 'Grad_Year',
#        'Class_Standing', 'GPA', 'Semester_Units', 'Transfer',
#        'International_Student', 'Post_Grad_Plan', 'Industry', 'Planned_Role',
#        'Num_Football_Games', 'Social_Greek_Life_Status',
#        'Prof_Greek_Life_Status', 'Prof_Org_Status', 'Cultural_Org_Status',
#        'Religious_Org_Status', 'Sports_Org_Status', 'USC_Social_Exp',
#        'Merit_Scholarship_Percent', 'Paid_Job_Status', 'Time_Spent_Working',
#        'Time_Spent_Friends', 'Time_Spent_Family', 'Study_Alone',
#        'Time_Spent_Classwork', 'Overall_USC_Exp', 'Sex', 'Age', 'Home_Country',
#        'Zip_Code_US', 'Is_California_Home', 'Languages_Spoken', 'News_Source',
# ...

# %% [markdown]
# В ячейке ниже заполните заготовку, чтобы:
# - `num_cols` хранит количество столбцов в `df`

# %%
### edTest(test_b) ###
num_rows = df.shape[0]
num_cols = df.shape[1]

# %% [markdown]
# В ячейке ниже заполните заготовку, чтобы `sneak_peak` был равен первым 7 рядам. ([HINT](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html))

# %%
### edTest(test_c) ###
sneak_peak = df.loc[:6]
sneak_peak
# Out:
#   16Personalities Quiz.  You will need to first take the quiz located at https://www.16personalities.com/. This quiz will take about 10 miinutes. Select your personality letters below. E.g. ENTJ-A, INTP-A, etc.  \
# 0                                             ISFJ-A
# 1                                             ISFJ-A
# 2                                             INFJ-A
# 3                                             ESFP-A
# 4                                             ENFP-T
# 5                                             ENTP-A
# 6                                             ESTJ-A
#
#                                       Major_1 Major_2              Minor_1  \
# 0                     Business Administration     NaN    Applied Analytics
# 1                     Business Administration     NaN    Applied Analytics
# 2                     International Relations     NaN  Applied Analytics m
# 3                                   Econ&Math     NaN    Applied Analytics
# ...

# %% [markdown]
# В ячейке ниже заполните заготовку, чтобы `the_end` равен последним 4 рядам.([Подсказка] (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.dataframe.tail.html))

# %%
### edTest(test_d) ###
the_end = df.loc[(df.shape[0]-4):(df.shape[0])]
the_end
# Out:
#    16Personalities Quiz.  You will need to first take the quiz located at https://www.16personalities.com/. This quiz will take about 10 miinutes. Select your personality letters below. E.g. ENTJ-A, INTP-A, etc.  \
# 94                                             ENTJ-A
# 95                                             ENFP-A
# 96                                             ESTJ-A
# 97                                             ENFP-T
#
#                      Major_1       Major_2            Minor_1     Minor_2  \
# 94   Business Administration           NaN  Applied Analytics         NaN
# 95  Business Administration            NaN  Applied Analytics  Psychology
# 96                 Economics  Data Science               None         NaN
# 97                 Economics           NaN  Applied Analytics         NaN
#
#               PDP_Status  Grad_Year Class_Standing   GPA  Semester_Units  ...  \
# 94                    No       2024         Junior  3.83              18  ...
# ...

# %% [markdown]
# В ячейке ниже заполните заготовку, чтобы переменная `python_experiences` хранила список из 5 различных значений, найденных в столбце« Marjor_1»` df`.

# %%
### edTest(test_e) ###
python_experiences = pd.Series(df['Major_1'].unique()).sample(5).tolist()
python_experiences
# Out:
# ['Computer Science',
#  'Business Administration ',
#  'Business Administration (Business Analytics)',
#  'Business',
#  'industrial and systems engineering']

# %% [markdown]
# В ячейке ниже заполните заготовку так, чтобы переменная `economics' хранила **строки (ы)**, которые соответствуют всем, кто прошел курсы по экономике

# %%
### edTest(test_f) ###
economics = df.loc[df['Major_1'] == 'Economics']

economics
# Out:
#    16Personalities Quiz.  You will need to first take the quiz located at https://www.16personalities.com/. This quiz will take about 10 miinutes. Select your personality letters below. E.g. ENTJ-A, INTP-A, etc.  \
# 9                                              ENFP-T
# 44                                             INTJ-T
# 47                                             ENFJ-A
# 49                                             ESFJ-T
# 74                                             ENFJ-T
# 80                                             ENFP-A
# 81                                             ENFP-T
# 83                                             INTJ-A
# 90                                             ISFP-T
# 96                                             ESTJ-A
# 97                                             ENFP-T
#
#       Major_1                     Major_2             Minor_1  \
# 9   Economics                         NaN  Applied Analytics
# ...

# %% [markdown]
# В ячейке ниже заполните заготовку, чтобы переменная `gpa` хранила **строки данных DataFrame**, которые соответствуют всем, у кого gpa выше 3,9

# %%
### edTest(test_g) ###
gpa = df.loc[df['GPA'] > 3.9]
gpa
# Out:
#    16Personalities Quiz.  You will need to first take the quiz located at https://www.16personalities.com/. This quiz will take about 10 miinutes. Select your personality letters below. E.g. ENTJ-A, INTP-A, etc.  \
# 0                                              ISFJ-A
# 1                                              ISFJ-A
# 2                                              INFJ-A
# 5                                              ENTP-A
# 10                                             ISFJ-T
# 31                                             ESFP-T
# 32                                             ENFP-A
# 40                                             ESFJ-T
# 45                                             ISFJ-T
# 47                                             ENFJ-A
# 66                                             ENFP-T
# 74                                             ENFJ-T
# 77                                             INTJ-T
# ...

# %% [markdown]
# В ячейке ниже заполните заготовку, чтобы переменная `row56` хранила ** 56 -ю строку **` df`.Чтобы быть ясным, представьте, что наш флаг данных выглядел следующим образом:
#
# ПолемНазовите возраст \
# 0 Энрике 25 \
# 1 Шейла 67 \
# 2 Марси 21 \
# 3 utibe 33
#
# Мы бы сказали, что 1 -й ряд - это тот, который с Энрике, 2 -й ряд - это тот, с Шейлой, 3 -й ряд - тот, который с Марси и т. Д.

# %%
### edTest(test_h) ###
row56 = df.iloc[[55]]
row56
# Out:
#    16Personalities Quiz.  You will need to first take the quiz located at https://www.16personalities.com/. This quiz will take about 10 miinutes. Select your personality letters below. E.g. ENTJ-A, INTP-A, etc.  \
# 55                                             ENTJ-T
#
#                                 Major_1 Major_2            Minor_1 Minor_2  \
# 55  Philosophy, Politics, and Economics     NaN  Applied Analytics     NaN
#
#               PDP_Status  Grad_Year Class_Standing   GPA  Semester_Units  ...  \
# 55  Planning on joining.       2023         Senior  3.85              16  ...
#
#    Zip_Code_US Is_California_Home Languages_Spoken News_Source  \
# 55       30030                Yes              1.0       Other
#
#    Loves_to_Travel Foodie Purchase_Based_On_Sustainability  \
# 55             Yes    Yes                              Yes
#
#    Reusable_Water_Bottle Meals_Delivery_Service_Percent Ride_Share_Percent
# ...

# %% [markdown]
# В ячейке ниже заполните заготовку, чтобы `sorded_df` теперь хранит` df` после сортировки по столбцу имени в порядке возрастания (a -> z)

# %%
### edTest(test_i) ###
sorted_df = df.sort_values(by = 'Class_Standing', ascending = True)
sorted_df.head()
# Out:
#    16Personalities Quiz.  You will need to first take the quiz located at https://www.16personalities.com/. This quiz will take about 10 miinutes. Select your personality letters below. E.g. ENTJ-A, INTP-A, etc.  \
# 83                                             INTJ-A
# 0                                              ISFJ-A
# 49                                             ESFJ-T
# 43                                             ISFP-T
# 64                                             INFJ-T
#
#                     Major_1                     Major_2            Minor_1  \
# 83                Economics  Environmental Data Science  Applied Analytics
# 0   Business Administration                         NaN  Applied Analytics
# 49                Economics                         NaN  Applied Analytics
# 43             Data Science                 Mathematics               None
# 64  Business Administration                         NaN  Applied Analytics
#
# ...

# %% [markdown]
# В ячейке ниже заполните заготовку, чтобы `sorted_row56` хранит 56 -й ряд` sorted_df`.Чтобы быть ясным, представьте, что наш отсортированный фрейм выглядел следующим образом:
#
# . Name        Age \
# 0 Enrique  25 \
# 2 Marcy    21 \
# 1 Sheila   67 \
# 3 Utibe    33
# Мы бы сказали, что 1 -й ряд - это тот, который с Энрике, 2 -й ряд - это тот, с Марси, 3 -й ряд - это тот, который с Шейлой и т. Д.

# %%
### edTest(test_j) ###
sorted_row56 =sorted_df.iloc[[55]]

sorted_row56
# Out:
#    16Personalities Quiz.  You will need to first take the quiz located at https://www.16personalities.com/. This quiz will take about 10 miinutes. Select your personality letters below. E.g. ENTJ-A, INTP-A, etc.  \
# 53                                             ESFJ-A
#
#                                     Major_1 Major_2           Minor_1 Minor_2  \
# 53  International Relations Global Business     NaN  Appled Analytics     NaN
#
#    PDP_Status  Grad_Year Class_Standing  GPA  Semester_Units  ... Zip_Code_US  \
# 53         No       2023         Senior  3.7              17  ...         NaN
#
#    Is_California_Home Languages_Spoken  \
# 53                Yes              3.0
#
#                                           News_Source Loves_to_Travel Foodie  \
# 53  Instagram,Facebook,Twitter,Google News,News Si...             Yes     No
#
#    Purchase_Based_On_Sustainability Reusable_Water_Bottle  \
# 53                              Yes                   Yes
#
# ...
