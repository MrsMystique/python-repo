# %% [markdown]
# # Seminar 09

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# - Прочесть с помощью pandas файл california_housing_test.csv, который находится в папке sample_data
# - Посмотреть сколько в нем строк и столбцов
# - Определить какой тип данных имеют столбцы

# %%
df = pd.read_csv('california_housing.csv')

# %%
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# - Проверить есть ли в файле пустые значения
# - Показать median_house_value где median_income < 2
# - Показать данные в первых 2 столбцах
# - Выбрать данные где housing_median_age < 20 и median_house_value > 70000

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df[df['median_income'] < 2][['median_house_value']]
# Out:
#        median_house_value
# 0                 66900.0
# 1                 80100.0
# 2                 85700.0
# 4                 65500.0
# 7                 48500.0
# ...                   ...
# 16984             70000.0
# 16989             58100.0
# 16990             78300.0
# 16994             76100.0
# 16998             85800.0
#
# [2005 rows x 1 columns]

# %%
df.iloc[:, :2]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df[['longitude', 'latitude']]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df['median_house_value'].min(), df['median_house_value'].max()
# Out:
# (14999.0, 500001.0)

# %%
# Выбрать данные где housing_median_age < 20 и median_house_value > 70000
df[
   (df['housing_median_age'] < 20) & 
   (df['median_house_value'] > 70000)
]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# 23       -114.98     33.82                15.0        644.0           129.0
# ...          ...       ...                 ...          ...             ...
# 16976    -124.17     40.75                13.0       2171.0           339.0
# 16983    -124.19     41.78                15.0       3140.0           714.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
# ...

# %% [markdown]
# Визуализировать longitude по отношения к median_house_value, используя линейный график
# Представить гистограмму по housing_median_age
# Изобразить гистограмму по median_house_value с оттенком housing_median_age

# %%
data = df.head(200)
data.plot(x ='longitude', y ='median_house_value')
# используется plt.show(), чтобы отобразить график. plt - это сокращение для matplotlib.pyplot, библиотеки для визуализации данных, которая используется в Pandas.
plt.show()

# %%
df = df.head(200)

sns.scatterplot(data = df, x = "median_house_value", y = "population", hue = "housing_median_age")
sns.scatterplot(data = df, x = "housing_median_age", y = "population", hue = "population")
# Out:
# <Axes: xlabel='median_house_value', ylabel='population'>

# %%
sns.lineplot(data = df, x ="population", y="housing_median_age")
# Out:
# <Axes: xlabel='population', ylabel='housing_median_age'>

# %%
plt.subplot(1, 2, 1)
sns.countplot(x='population', data= df)
plt.subplot(1, 2, 2)
sns.countplot(x='housing_median_age', data= df)
# Out:
# <Axes: xlabel='housing_median_age', ylabel='count'>

# %%
sns.set_style("whitegrid")
sns.lineplot(data = df.head(10), x="population", y="housing_median_age")
# Out:
# <Axes: xlabel='population', ylabel='housing_median_age'>

# %%
sns.lineplot(data= df.head(100), x="housing_median_age", y="population",color="r")

plt.title("Title of plot of housing")
plt.xlabel("Age (years)")
plt.ylabel("Population")
plt.show()

# %%
sns.histplot(data = df.head(1000), x='median_house_value', y='housing_median_age', legend=False)
# Out:
# <Axes: xlabel='median_house_value', ylabel='housing_median_age'>

# %%
plt.figure(figsize=(20,7))

sns.lineplot(data = df.head(1000), x= "population", y= "median_house_value", hue="median_house_value")

plt.title("TITLE PLOT")
plt.xlabel("population")
plt.ylabel("median_house_value")
plt.show()

# %%
pg = sns.load_dataset("penguins")
pg.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
pg.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
pg.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
pg = pg.dropna()

# %%
pg[['species', 'island']].describe()
# Out:
#        species  island
# count      333     333
# unique       3       3
# top     Adelie  Biscoe
# freq       146     163

# %%
plt.subplot(1, 2, 1)
sns.countplot(x='sex', data= pg)
plt.subplot(1, 2, 2)
sns.countplot(x='island', data= pg)
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
pg.corr(method ='pearson')
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_16716/3911810757.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pg.corr(method ='pearson')
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
g = sns.PairGrid(pg, hue="species", diag_sharey=False)
g.map_upper(sns.scatterplot, color=".3")
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot)

# %%
g = sns.PairGrid(pg, hue="species")
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
variables = ["body_mass_g", "bill_length_mm", "flipper_length_mm"]
g = sns.PairGrid(pg, hue="body_mass_g", vars = variables)
g.map_diag(sns.histplot, hue= None, color=".3")
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
g = sns.PairGrid(pg, hue="body_mass_g")
g.map_diag(sns.histplot, hue= None, color=".3")
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
g = sns.PairGrid(pg)
g.map(sns.scatterplot)

# %% [markdown]
# Создать новый столбец в таблице с пингвинами, который будет отвечать  за показатель длины клюва пингвина.
# high - длинный(от 42)
# middle - средний(от 35 до 42)
# low - маленький(до 35)

# %%
df.loc[df['bill_length_mm'] >= 42, 'height_group'] = 'high'
df.loc[(df['bill_length_mm'] >= 35) & (df['bill_length_mm'] < 42), 'height_group'] = 'middle'
df.loc[df['bill_length_mm'] < 35, 'height_group'] = 'low'

# %%
sns.heatmap(pg.corr())
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_16716/496030519.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(pg.corr())
# <Axes: >

# %%
num_col = ['age', 'nr_employed']

for col in num_col:
    
    fig = plt.figure()
    fig.set_size_inches(16, 10)
    
    sns.boxplot(y=col, x=df['y'].astype('category'), data=df)
    
    plt.show()

# %%
for col in categorical_columns:
    g = sns.catplot(x=col, kind='count', col='y', data=df, sharey=False)
    g.set_xticklabels(rotation=60)
